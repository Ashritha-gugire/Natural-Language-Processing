# %% [markdown]
# ## Named Entity Recognition and De-Identification with SpaCy
# ### Task1 - NER(Named Entity Recognition)

# %%
#1.1)Copy the code examples to scrape the webpage in BeautifulSoup
import bs4 as bs#BeautifulSoup
import urllib.request

import spacy
import en_core_web_sm

from spacy import displacy
from collections import Counter
from pprint import pprint

# %%
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# %%
#scrapping the text data from webpage with Bs
def _scrape_webpage(url):
    
    scraped_textdata = urllib.request.urlopen(url)
    textdata = scraped_textdata.read()
    parsed_textdata = bs.BeautifulSoup(textdata,'lxml')
    paragraphs = parsed_textdata.find_all('p')
    formated_text = ""
    for para in paragraphs:
        formated_text += para.text
    return formated_text

# %%
# I have taken this post from Washingtonpost, this article explains about Sun, its solar flares and radiation. posted in 
#washingtonpost on February 22, 2024.
mytext = _scrape_webpage('https://www.washingtonpost.com/weather/2024/02/22/solar-flares-cycle-xclass-radio-att/')

# %%
#1.2 Write the code for NER in SpaCy 
doc = nlp(mytext)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Three 0 5 CARDINAL
# Wednesday and Thursday 65 87 DATE
# first 93 98 ORDINAL
# two 99 102 CARDINAL
# seven hours 112 123 TIME
# X1.6 153 157 ORG
# third 186 191 ORDINAL
# 11-year 226 233 DATE
# 11-year 548 555 DATE
# 25 595 597 CARDINAL
# this year 629 638 DATE
# Earth 834 839 LOC
# Earth 919 924 LOC
# at least a day 959 973 DATE
# three 978 983 CARDINAL
# Earth 1056 1061 LOC
# first 1071 1076 ORDINAL
# two 1077 1080 CARDINAL
# CME 1106 1109 ORG
# third 1168 1173 ORDINAL
# Earth 1235 1240 LOC
# Earth 1319 1324 LOC
# Earth 1357 1362 LOC
# between 50 and 600 miles 1376 1400 CARDINAL
# Earth 1474 1479 LOC
# Three 1796 1801 CARDINAL
# Pacific 1898 1905 LOC
# Indian 1910 1916 NORP
# R3 1942 1944 PRODUCT
# 1 1962 1963 CARDINAL
# 5 1972 1973 CARDINAL
# the National Oceanic and Atmospheric Administration’s 1993 2046 ORG
# about an hour 2191 2204 TIME
# Earth 2223 2228 LOC
# Thursday 2368 2376 DATE
# morning 2377 2384 TIME
# AT&T 2397 2401 ORG
# Wednesday 2423 2432 DATE
# The Space Weather Prediction Center 2449 2484 ORG
# Kunches 2626 2633 PERSON
# The Washington Post 2682 2701 ORG
# the night hours 2768 2783 TIME
# North America 2788 2801 LOC
# Kunches 2937 2944 PERSON
# daylight hours 3007 3021 TIME
# 3 3226 3227 CARDINAL
# 30 3231 3233 CARDINAL
# megahertz 3234 3243 ORG
# 698 3290 3293 CARDINAL
# 806 3298 3301 CARDINAL
# Wednesday 3322 3331 DATE
# February of 2022 3494 3510 DATE
# 40 3512 3514 CARDINAL
# CME 3555 3558 ORG
# CME 3582 3585 ORG
# more than a day 3616 3631 DATE
# Earth 3641 3646 LOC
# first 3659 3664 ORDINAL
# two 3665 3668 CARDINAL
# Wednesday 3679 3688 DATE
# Earth 3840 3845 LOC
# third 3850 3855 ORDINAL
# Thursday 3904 3912 DATE
# evening 3913 3920 TIME
# Eastern 3921 3928 ORG
# several hours 4028 4041 TIME
# Sunday night 4325 4337 TIME
# CME 4349 4352 ORG
# Earth 4393 4398 LOC
# the days ahead 4462 4476 DATE
# three 4523 4528 CARDINAL
# Active Region 3590 4538 4556 WORK_OF_ART

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(Three, 'B', 'CARDINAL'),
#  (top, 'O', ''),
#  (-, 'O', ''),
#  (tier, 'O', ''),
#  (X, 'O', ''),
#  (-, 'O', ''),
#  (class, 'O', ''),
#  (solar, 'O', ''),
#  (flares, 'O', ''),
#  (launched, 'O', ''),
#  (off, 'O', ''),
#  (the, 'O', ''),
#  (sun, 'O', ''),
#  (between, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (and, 'I', 'DATE'),
#  (Thursday, 'I', 'DATE'),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (two, 'B', 'CARDINAL'),
#  (occurred, 'O', ''),
#  (seven, 'B', 'TIME'),
#  (hours, 'I', 'TIME'),
#  (apart, 'O', ''),
#  (,, 'O', ''),
#  (coming, 'O', ''),
#  (in, 'O', ''),
#  (at, 'O', ''),
#  (X1.9, 'O', ''),
#  (and, 'O', ''),
#  (X1.6, 'B', 'ORG'),
#  (magnitude, 'O', ''),
#  (respectively, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (third, 'B', 'ORDINAL'),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (most, 'O', ''),
#  (powerful, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (current, 'O', ''),
#  (11, 'B', 'DATE'),
#  (-, 'I', 'DATE'),
#  (year, 'I', 'DATE'),
#  (“, 'O', ''),
#  (solar, 'O', ''),
#  (cycle, 'O', ''),
#  (,, 'O', ''),
#  (”, 'O', ''),
#  (ranked, 'O', ''),
#  (an, 'O', ''),
#  (impressive, 'O', ''),
#  (X6.3.Solar, 'O', ''),
#  (flares, 'O', ''),
#  (,, 'O', ''),
#  (or, 'O', ''),
#  (bursts, 'O', ''),
#  (of, 'O', ''),
#  (radiation, 'O', ''),
#  (,, 'O', ''),
#  (are, 'O', ''),
#  (ranked, 'O', ''),
#  (on, 'O', ''),
#  (a, 'O', ''),
#  (scale, 'O', ''),
#  (that, 'O', ''),
#  (goes, 'O', ''),
#  (from, 'O', ''),
#  (A, 'O', ''),
#  (,, 'O', ''),
#  (B, 'O', ''),
#  (and, 'O', ''),
#  (C, 'O', ''),
#  (to, 'O', ''),
#  (M, 'O', ''),
#  (and, 'O', ''),
#  (X, 'O', ''),
#  (,, 'O', ''),
#  (in, 'O', ''),
#  (increasing, 'O', ''),
#  (order, 'O', ''),
#  (of, 'O', ''),
#  (intensity, 'O', ''),
#  (., 'O', ''),
#  (They, 'O', ''),
#  (usually, 'O', ''),
#  (originate, 'O', ''),
#  (from, 'O', ''),
#  (sunspots, 'O', ''),
#  (,, 'O', ''),
#  (or, 'O', ''),
#  (bruiselike, 'O', ''),
#  (discolorations, 'O', ''),
#  (on, 'O', ''),
#  (the, 'O', ''),
#  (surface, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (sun, 'O', ''),
#  (., 'O', ''),
#  (Sunspots, 'O', ''),
#  (are, 'O', ''),
#  (most, 'O', ''),
#  (common, 'O', ''),
#  (near, 'O', ''),
#  (the, 'O', ''),
#  (height, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (11, 'B', 'DATE'),
#  (-, 'I', 'DATE'),
#  (year, 'I', 'DATE'),
#  (solar, 'O', ''),
#  (cycle, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (current, 'O', ''),
#  (cycle, 'O', ''),
#  (,, 'O', ''),
#  (number, 'O', ''),
#  (25, 'B', 'CARDINAL'),
#  (,, 'O', ''),
#  (is, 'O', ''),
#  (expected, 'O', ''),
#  (to, 'O', ''),
#  (reach, 'O', ''),
#  (its, 'O', ''),
#  (peak, 'O', ''),
#  (this, 'B', 'DATE'),
#  (year, 'I', 'DATE'),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (more, 'O', ''),
#  (sunspots, 'O', ''),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (more, 'O', ''),
#  (opportunities, 'O', ''),
#  (for, 'O', ''),
#  (solar, 'O', ''),
#  (flares, 'O', ''),
#  (., 'O', ''),
#  (Solar, 'O', ''),
#  (flares, 'O', ''),
#  (and, 'O', ''),
#  (accompanying, 'O', ''),
#  (coronal, 'O', ''),
#  (mass, 'O', ''),
#  (ejections, 'O', ''),
#  (,, 'O', ''),
#  (or, 'O', ''),
#  (CMEs, 'O', ''),
#  (,, 'O', ''),
#  (can, 'O', ''),
#  (influence, 'O', ''),
#  (“, 'O', ''),
#  (space, 'O', ''),
#  (weather, 'O', ''),
#  (”, 'O', ''),
#  (across, 'O', ''),
#  (the, 'O', ''),
#  (solar, 'O', ''),
#  (system, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (even, 'O', ''),
#  (here, 'O', ''),
#  (on, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (., 'O', ''),
#  (CMEs, 'O', ''),
#  (are, 'O', ''),
#  (slower, 'O', ''),
#  (shock, 'O', ''),
#  (waves, 'O', ''),
#  (of, 'O', ''),
#  (magnetic, 'O', ''),
#  (energy, 'O', ''),
#  (from, 'O', ''),
#  (the, 'O', ''),
#  (sun, 'O', ''),
#  (., 'O', ''),
#  (Flares, 'O', ''),
#  (can, 'O', ''),
#  (reach, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (in, 'O', ''),
#  (minutes, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (CMEs, 'O', ''),
#  (usually, 'O', ''),
#  (take, 'O', ''),
#  (at, 'B', 'DATE'),
#  (least, 'I', 'DATE'),
#  (a, 'I', 'DATE'),
#  (day, 'I', 'DATE'),
#  (., 'O', ''),
#  (All, 'O', ''),
#  (three, 'B', 'CARDINAL'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (X, 'O', ''),
#  (-, 'O', ''),
#  (class, 'O', ''),
#  (solar, 'O', ''),
#  (flares, 'O', ''),
#  (disrupted, 'O', ''),
#  (shortwave, 'O', ''),
#  (radio, 'O', ''),
#  (communications, 'O', ''),
#  (on, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (., 'O', ''),
#  (But, 'O', ''),
#  (the, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (two, 'B', 'CARDINAL'),
#  (flares, 'O', ''),
#  (did, 'O', ''),
#  (not, 'O', ''),
#  (release, 'O', ''),
#  (a, 'O', ''),
#  (CME, 'B', 'ORG'),
#  (., 'O', ''),
#  (And, 'O', ''),
#  (,, 'O', ''),
#  (after, 'O', ''),
#  (careful, 'O', ''),
#  (review, 'O', ''),
#  (,, 'O', ''),
#  (scientists, 'O', ''),
#  (confirmed, 'O', ''),
#  (that, 'O', ''),
#  (the, 'O', ''),
#  (third, 'B', 'ORDINAL'),
#  (also, 'O', ''),
#  (did, 'O', ''),
#  (not, 'O', ''),
#  (produce, 'O', ''),
#  (one, 'O', ''),
#  (., 'O', ''),
#  (Therefore, 'O', ''),
#  (,, 'O', ''),
#  (no, 'O', ''),
#  (additional, 'O', ''),
#  (impact, 'O', ''),
#  (on, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (is, 'O', ''),
#  (expected, 'O', ''),
#  (., 'O', ''),
#  (High, 'O', ''),
#  (-, 'O', ''),
#  (frequency, 'O', ''),
#  (radio, 'O', ''),
#  (waves, 'O', ''),
#  (propagate, 'O', ''),
#  (by, 'O', ''),
#  (bouncing, 'O', ''),
#  (off, 'O', ''),
#  (electrons, 'O', ''),
#  (in, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (’s, 'O', ''),
#  (ionosphere, 'O', ''),
#  (., 'O', ''),
#  (That, 'O', ''),
#  (’s, 'O', ''),
#  (a, 'O', ''),
#  (layer, 'O', ''),
#  (of, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (’s, 'O', ''),
#  (atmosphere, 'O', ''),
#  (between, 'B', 'CARDINAL'),
#  (50, 'I', 'CARDINAL'),
#  (and, 'I', 'CARDINAL'),
#  (600, 'I', 'CARDINAL'),
#  (miles, 'I', 'CARDINAL'),
#  (above, 'O', ''),
#  (the, 'O', ''),
#  (groundWhen, 'O', ''),
#  (a, 'O', ''),
#  (solar, 'O', ''),
#  (flare, 'O', ''),
#  (occurs, 'O', ''),
#  (,, 'O', ''),
#  (that, 'O', ''),
#  (radiation, 'O', ''),
#  (travels, 'O', ''),
#  (toward, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (speed, 'O', ''),
#  (of, 'O', ''),
#  (light, 'O', ''),
#  (., 'O', ''),
#  (It, 'O', ''),
#  (can, 'O', ''),
#  (ionize, 'O', ''),
#  (additional, 'O', ''),
#  (particles, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (lower, 'O', ''),
#  (ionosphere, 'O', ''),
#  (., 'O', ''),
#  (Radio, 'O', ''),
#  (waves, 'O', ''),
#  (sent, 'O', ''),
#  (from, 'O', ''),
#  (devices, 'O', ''),
#  (below, 'O', ''),
#  (it, 'O', ''),
#  (then, 'O', ''),
#  (impact, 'O', ''),
#  (that, 'O', ''),
#  (extra, 'O', ''),
#  (-, 'O', ''),
#  (ionized, 'O', ''),
#  (layer, 'O', ''),
#  (and, 'O', ''),
#  (lose, 'O', ''),
#  (energy, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (are, 'O', ''),
#  (n’t, 'O', ''),
#  (able, 'O', ''),
#  (to, 'O', ''),
#  (be, 'O', ''),
#  (bent, 'O', ''),
#  (by, 'O', ''),
#  (ions, 'O', ''),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (top, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (ionosphere, 'O', ''),
#  (., 'O', ''),
#  (That, 'O', ''),
#  (means, 'O', ''),
#  (signals, 'O', ''),
#  (ca, 'O', ''),
#  (n’t, 'O', ''),
#  (travel, 'O', ''),
#  (very, 'O', ''),
#  (far, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (radio, 'O', ''),
#  (blackouts, 'O', ''),
#  (are, 'O', ''),
#  (possible, 'O', ''),
#  (., 'O', ''),
#  (Three, 'B', 'CARDINAL'),
#  (back, 'O', ''),
#  (-, 'O', ''),
#  (to, 'O', ''),
#  (-, 'O', ''),
#  (back, 'O', ''),
#  (radio, 'O', ''),
#  (blackouts, 'O', ''),
#  (occurred, 'O', ''),
#  (in, 'O', ''),
#  (response, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (trio, 'O', ''),
#  (of, 'O', ''),
#  (flares, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (primarily, 'O', ''),
#  (over, 'O', ''),
#  (the, 'O', ''),
#  (Pacific, 'B', 'LOC'),
#  (and, 'O', ''),
#  (Indian, 'B', 'NORP'),
#  (oceans, 'O', ''),
#  (., 'O', ''),
#  (They, 'O', ''),
#  (were, 'O', ''),
#  (rated, 'O', ''),
#  (“, 'O', ''),
#  (R3, 'B', 'PRODUCT'),
#  (”, 'O', ''),
#  (or, 'O', ''),
#  (greater, 'O', ''),
#  (on, 'O', ''),
#  (a, 'O', ''),
#  (1, 'B', 'CARDINAL'),
#  (through, 'O', ''),
#  (5, 'B', 'CARDINAL'),
#  (scale, 'O', ''),
#  (., 'O', ''),
#  (According, 'O', ''),
#  (to, 'O', ''),
#  (the, 'B', 'ORG'),
#  (National, 'I', 'ORG'),
#  (Oceanic, 'I', 'ORG'),
#  (and, 'I', 'ORG'),
#  (Atmospheric, 'I', 'ORG'),
#  (Administration, 'I', 'ORG'),
#  (’s, 'I', 'ORG'),
#  (Space, 'O', ''),
#  (Weather, 'O', ''),
#  (Prediction, 'O', ''),
#  (Center, 'O', ''),
#  (,, 'O', ''),
#  (that, 'O', ''),
#  (results, 'O', ''),
#  (in, 'O', ''),
#  (a, 'O', ''),
#  (“, 'O', ''),
#  (wide, 'O', ''),
#  (area, 'O', ''),
#  (blackout, 'O', ''),
#  (of, 'O', ''),
#  ([, 'O', ''),
#  (high, 'O', ''),
#  (frequency, 'O', ''),
#  (], 'O', ''),
#  (radio, 'O', ''),
#  (communication, 'O', ''),
#  (,, 'O', ''),
#  ([, 'O', ''),
#  (and, 'O', ''),
#  (], 'O', ''),
#  (loss, 'O', ''),
#  (of, 'O', ''),
#  (radio, 'O', ''),
#  (contact, 'O', ''),
#  (for, 'O', ''),
#  (about, 'B', 'TIME'),
#  (an, 'I', 'TIME'),
#  (hour, 'I', 'TIME'),
#  (on, 'O', ''),
#  (sunlit, 'O', ''),
#  (side, 'O', ''),
#  (of, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (., 'O', ''),
#  (”, 'O', ''),
#  (Low, 'O', ''),
#  (-, 'O', ''),
#  (frequency, 'O', ''),
#  (navigation, 'O', ''),
#  (signals, 'O', ''),
#  (,, 'O', ''),
#  (like, 'O', ''),
#  (those, 'O', ''),
#  (used, 'O', ''),
#  (on, 'O', ''),
#  (aircraft, 'O', ''),
#  (traveling, 'O', ''),
#  (overseas, 'O', ''),
#  (,, 'O', ''),
#  (can, 'O', ''),
#  (be, 'O', ''),
#  (degraded, 'O', ''),
#  (too, 'O', ''),
#  (., 'O', ''),
#  (There, 'O', ''),
#  (was, 'O', ''),
#  (rampant, 'O', ''),
#  (speculation, 'O', ''),
#  (that, 'O', ''),
#  (Thursday, 'B', 'DATE'),
#  (morning, 'B', 'TIME'),
#  (’s, 'O', ''),
#  (pervasive, 'O', ''),
#  (AT&T, 'B', 'ORG'),
#  (blackout, 'O', ''),
#  (was, 'O', ''),
#  (tied, 'O', ''),
#  (to, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (’s, 'O', ''),
#  (solar, 'O', ''),
#  (flares, 'O', ''),
#  (., 'O', ''),
#  (The, 'B', 'ORG'),
#  (Space, 'I', 'ORG'),
#  (Weather, 'I', 'ORG'),
#  (Prediction, 'I', 'ORG'),
#  (Center, 'I', 'ORG'),
#  (,, 'O', ''),
#  (however, 'O', ''),
#  (,, 'O', ''),
#  (released, 'O', ''),
#  (a, 'O', ''),
#  (statement, 'O', ''),
#  (noting, 'O', ''),
#  (that, 'O', ''),
#  (“, 'O', ''),
#  (it, 'O', ''),
#  (is, 'O', ''),
#  (unlikely, 'O', ''),
#  (that, 'O', ''),
#  (these, 'O', ''),
#  (flares, 'O', ''),
#  (contributed, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (widely, 'O', ''),
#  (reported, 'O', ''),
#  (cellular, 'O', ''),
#  (network, 'O', ''),
#  (outage, 'O', ''),
#  (., 'O', ''),
#  (”Joe, 'O', ''),
#  (Kunches, 'B', 'PERSON'),
#  (,, 'O', ''),
#  (former, 'O', ''),
#  (chief, 'O', ''),
#  (of, 'O', ''),
#  (operations, 'O', ''),
#  (at, 'O', ''),
#  (the, 'O', ''),
#  (center, 'O', ''),
#  (,, 'O', ''),
#  (told, 'O', ''),
#  (The, 'B', 'ORG'),
#  (Washington, 'I', 'ORG'),
#  (Post, 'I', 'ORG'),
#  (that, 'O', ''),
#  (“, 'O', ''),
#  (there, 'O', ''),
#  (is, 'O', ''),
#  (no, 'O', ''),
#  (chance, 'O', ''),
#  (”, 'O', ''),
#  (of, 'O', ''),
#  (any, 'O', ''),
#  (connection, 'O', ''),
#  (., 'O', ''),
#  (“First, 'O', ''),
#  (it, 'O', ''),
#  (occurred, 'O', ''),
#  (in, 'O', ''),
#  (the, 'B', 'TIME'),
#  (night, 'I', 'TIME'),
#  (hours, 'I', 'TIME'),
#  (for, 'O', ''),
#  (North, 'B', 'LOC'),
#  (America, 'I', 'LOC'),
#  (,, 'O', ''),
#  (so, 'O', ''),
#  (any, 'O', ''),
#  (possible, 'O', ''),
#  (impact, 'O', ''),
#  (would, 'O', ''),
#  (have, 'O', ''),
#  (not, 'O', ''),
#  (occurred, 'O', ''),
#  (here, 'O', ''),
#  (., 'O', ''),
#  (Flares, 'O', ''),
#  (and, 'O', ''),
#  (their, 'O', ''),
#  (associated, 'O', ''),
#  (radio, 'O', ''),
#  (bursts, 'O', ''),
#  (only, 'O', ''),
#  (impact, 'O', ''),
#  (dayside, 'O', ''),
#  (systems, 'O', ''),
#  (if, 'O', ''),
#  (at, 'O', ''),
#  (all, 'O', ''),
#  (,, 'O', ''),
#  (”, 'O', ''),
#  (Kunches, 'B', 'PERSON'),
#  (said, 'O', ''),
#  (in, 'O', ''),
#  (an, 'O', ''),
#  (email, 'O', ''),
#  (., 'O', ''),
#  (“, 'O', ''),
#  (And, 'O', ''),
#  (,, 'O', ''),
#  (even, 'O', ''),
#  (if, 'O', ''),
#  (this, 'O', ''),
#  (was, 'O', ''),
#  (to, 'O', ''),
#  (occur, 'O', ''),
#  (during, 'O', ''),
#  (your, 'O', ''),
#  (daylight, 'B', 'TIME'),
#  (hours, 'I', 'TIME'),
#  (,, 'O', ''),
#  (chances, 'O', ''),
#  (are, 'O', ''),
#  (near, 'O', ''),
#  (nil, 'O', ''),
#  (that, 'O', ''),
#  (cell, 'O', ''),
#  (service, 'O', ''),
#  (would, 'O', ''),
#  (be, 'O', ''),
#  (affected, 'O', ''),
#  (., 'O', ''),
#  (”Solar, 'O', ''),
#  (flares, 'O', ''),
#  (do, 'O', ''),
#  (n’t, 'O', ''),
#  (usually, 'O', ''),
#  (affect, 'O', ''),
#  (cellphone, 'O', ''),
#  (frequencies, 'O', ''),
#  (., 'O', ''),
#  (Radio, 'O', ''),
#  (blackouts, 'O', ''),
#  (associated, 'O', ''),
#  (with, 'O', ''),
#  (solar, 'O', ''),
#  (flares, 'O', ''),
#  (affect, 'O', ''),
#  (transmissions, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (high, 'O', ''),
#  (-, 'O', ''),
#  (frequency, 'O', ''),
#  (3, 'B', 'CARDINAL'),
#  (to, 'O', ''),
#  (30, 'B', 'CARDINAL'),
#  (megahertz, 'B', 'ORG'),
#  (band, 'O', ''),
#  (., 'O', ''),
#  (Most, 'O', ''),
#  (cellphone, 'O', ''),
#  (carriers, 'O', ''),
#  (operate, 'O', ''),
#  (between, 'O', ''),
#  (698, 'B', 'CARDINAL'),
#  (and, 'O', ''),
#  (806, 'B', 'CARDINAL'),
#  (megahertz, 'O', ''),
#  (., 'O', ''),
#  (Finally, 'O', ''),
#  (,, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (’s, 'O', ''),
#  (flares, 'O', ''),
#  (did, 'O', ''),
#  (n’t, 'O', ''),
#  (unleash, 'O', ''),
#  (CMEs, 'O', ''),
#  (., 'O', ''),
#  (Such, 'O', ''),
#  (blasts, 'O', ''),
#  (can, 'O', ''),
#  (induce, 'O', ''),
#  (electric, 'O', ''),
#  (currents, 'O', ''),
#  (that, 'O', ''),
#  (can, 'O', ''),
#  (overwhelm, 'O', ''),
#  (circuitry, 'O', ''),
#  (in, 'O', ''),
#  (satellites, 'O', ''),
#  (and, 'O', ''),
#  (even, 'O', ''),
#  (knock, 'O', ''),
#  (them, 'O', ''),
#  (offline, 'O', ''),
#  (or, 'O', ''),
#  (destroy, 'O', ''),
#  (them, 'O', ''),
#  (., 'O', ''),
#  (In, 'O', ''),
#  (February, 'B', 'DATE'),
#  (of, 'I', 'DATE'),
#  (2022, 'I', 'DATE'),
#  (,, 'O', ''),
#  (40, 'B', 'CARDINAL'),
#  (SpaceX, 'O', ''),
#  (satellites, 'O', ''),
#  (were, 'O', ''),
#  (knocked, 'O', ''),
#  (out, 'O', ''),
#  (by, 'O', ''),
#  (a, 'O', ''),
#  (CME, 'B', 'ORG'),
#  (., 'O', ''),
#  (Even, 'O', ''),
#  (had, 'O', ''),
#  (there, 'O', ''),
#  (been, 'O', ''),
#  (a, 'O', ''),
#  (CME, 'B', 'ORG'),
#  (,, 'O', ''),
#  (it, 'O', ''),
#  (probably, 'O', ''),
#  (would, 'O', ''),
#  (have, 'O', ''),
#  (taken, 'O', ''),
#  (more, 'B', 'DATE'),
#  (than, 'I', 'DATE'),
#  (a, 'I', 'DATE'),
#  (day, 'I', 'DATE'),
#  (to, 'O', ''),
#  (reach, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (., 'O', ''),
#  (Because, 'O', ''),
#  (the, 'O', ''),
#  (first, 'B', 'ORDINAL'),
#  (two, 'B', 'CARDINAL'),
#  (flares, 'O', ''),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (did, 'O', ''),
#  (n’t, 'O', ''),
#  (release, 'O', ''),
#  (CMEs, 'O', ''),
#  (,, 'O', ''),
#  (it, 'O', ''),
#  (means, 'O', ''),
#  (skywatchers, 'O', ''),
#  (wo, 'O', ''),
#  (n’t, 'O', ''),
#  (be, 'O', ''),
#  (treated, 'O', ''),
#  (to, 'O', ''),
#  (displays, 'O', ''),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (northern, 'O', ''),
#  (lights, 'O', ''),
#  (,, 'O', ''),
#  (as, 'O', ''),
#  (is, 'O', ''),
#  (often, 'O', ''),
#  (the, 'O', ''),
#  (case, 'O', ''),
#  (when, 'O', ''),
#  (such, 'O', ''),
#  (geomagnetic, 'O', ''),
#  (storms, 'O', ''),
#  (reach, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (third, 'B', 'ORDINAL'),
#  (solar, 'O', ''),
#  (flare, 'O', ''),
#  (,, 'O', ''),
#  (which, 'O', ''),
#  (was, 'O', ''),
#  (the, 'O', ''),
#  (biggest, 'O', ''),
#  (and, 'O', ''),
#  (occurred, 'O', ''),
#  (Thursday, 'B', 'DATE'),
#  (evening, 'B', 'TIME'),
#  (Eastern, 'B', 'ORG'),
#  (time, 'O', ''),
#  (,, 'O', ''),
#  (also, 'O', ''),
#  (did, 'O', ''),
#  (n’t, 'O', ''),
#  (produce, 'O', ''),
#  (a, 'O', ''),
#  (CME.Since, 'O', ''),
#  (CMEs, 'O', ''),
#  (are, 'O', ''),
#  (slower, 'O', ''),
#  (-, 'O', ''),
#  (moving, 'O', ''),
#  (than, 'O', ''),
#  (solar, 'O', ''),
#  (flares, 'O', ''),
#  (,, 'O', ''),
#  (it, 'O', ''),
#  (generally, 'O', ''),
#  (takes, 'O', ''),
#  (several, 'B', 'TIME'),
#  (hours, 'I', 'TIME'),
#  (for, 'O', ''),
#  (them, 'O', ''),
#  (to, 'O', ''),
#  (fully, 'O', ''),
#  (radiate, 'O', ''),
#  (away, 'O', ''),
#  (from, 'O', ''),
#  (the, 'O', ''),
#  (solar, 'O', ''),
#  (disk, 'O', ''),
#  (and, 'O', ''),
#  (become, 'O', ''),
#  (visible, 'O', ''),
#  (on, 'O', ''),
#  (sensors, 'O', ''),
#  (., 'O', ''),
#  (That, 'O', ''),
#  (’s, 'O', ''),
#  (why, 'O', ''),
#  (experts, 'O', ''),
#  (were, 'O', ''),
#  (n’t, 'O', ''),
#  (initially, 'O', ''),
#  (sure, 'O', ''),
#  (if, 'O', ''),
#  (any, 'O', ''),
#  (CMEs, 'O', ''),
#  (had, 'O', ''),
#  (been, 'O', ''),
#  (launched, 'O', ''),
#  (., 'O', ''),
#  (Now, 'O', ''),
#  (that, 'O', ''),
#  (time, 'O', ''),
#  (has, 'O', ''),
#  (passed, 'O', ''),
#  (,, 'O', ''),
#  (it, 'O', ''),
#  (’s, 'O', ''),
#  (apparent, 'O', ''),
#  (none, 'O', ''),
#  (were, 'O', ''),
#  (., 'O', ''),
#  (Interestingly, 'O', ''),
#  (,, 'O', ''),
#  (there, 'O', ''),
#  (could, 'O', ''),
#  (be, 'O', ''),
#  (a, 'O', ''),
#  (few, 'O', ''),
#  (auroral, 'O', ''),
#  (displays, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (high, 'O', ''),
#  (latitudes, 'O', ''),
#  (on, 'O', ''),
#  (Sunday, 'B', 'TIME'),
#  (night, 'I', 'TIME'),
#  (as, 'O', ''),
#  (a, 'O', ''),
#  (minor, 'O', ''),
#  (CME, 'B', 'ORG'),
#  (—, 'O', ''),
#  (unrelated, 'O', ''),
#  (to, 'O', ''),
#  (the, 'O', ''),
#  (flares, 'O', ''),
#  (--, 'O', ''),
#  (grazes, 'O', ''),
#  (the, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (., 'O', ''),
#  (There, 'O', ''),
#  (may, 'O', ''),
#  (be, 'O', ''),
#  (more, 'O', ''),
#  (opportunities, 'O', ''),
#  (for, 'O', ''),
#  (X, 'O', ''),
#  (-, 'O', ''),
#  (class, 'O', ''),
#  (flares, 'O', ''),
#  (and, 'O', ''),
#  (CMEs, 'O', ''),
#  (in, 'O', ''),
#  (the, 'B', 'DATE'),
#  (days, 'I', 'DATE'),
#  (ahead, 'I', 'DATE'),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (parent, 'O', ''),
#  (sunspot, 'O', ''),
#  (cluster, 'O', ''),
#  (that, 'O', ''),
#  (launched, 'O', ''),
#  (all, 'O', ''),
#  (three, 'B', 'CARDINAL'),
#  (,, 'O', ''),
#  (dubbed, 'O', ''),
#  (“, 'O', ''),
#  (Active, 'B', 'WORK_OF_ART'),
#  (Region, 'I', 'WORK_OF_ART'),
#  (3590, 'I', 'WORK_OF_ART'),
#  (,, 'O', ''),
#  (”, 'O', ''),
#  (is, 'O', ''),
#  (still, 'O', ''),
#  (crackling, 'O', ''),
#  (., 'O', ''),
#  (The, 'O', ''),
#  (sunspot, 'O', ''),
#  (is, 'O', ''),
#  (so, 'O', ''),
#  (big, 'O', ''),
#  (that, 'O', ''),
#  (you, 'O', ''),
#  (can, 'O', ''),
#  (view, 'O', ''),
#  (it, 'O', ''),
#  (with, 'O', ''),
#  (your, 'O', ''),
#  (own, 'O', ''),
#  (eyes, 'O', ''),
#  (—, 'O', ''),
#  (but, 'O', ''),
#  (you, 'O', ''),
#  (’ll, 'O', ''),
#  (need, 'O', ''),
#  (eclipse, 'O', ''),
#  (glasses, 'O', ''),
#  (to, 'O', ''),
#  (do, 'O', ''),
#  (so, 'O', ''),
#  (safely, 'O', ''),
#  (., 'O', '')]

# %%
#1.2.1 Get the named entities
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('Three', 'CARDINAL'),
#  ('Wednesday and Thursday', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('two', 'CARDINAL'),
#  ('seven hours', 'TIME'),
#  ('X1.6', 'ORG'),
#  ('third', 'ORDINAL'),
#  ('11-year', 'DATE'),
#  ('11-year', 'DATE'),
#  ('25', 'CARDINAL'),
#  ('this year', 'DATE'),
#  ('Earth', 'LOC'),
#  ('Earth', 'LOC'),
#  ('at least a day', 'DATE'),
#  ('three', 'CARDINAL'),
#  ('Earth', 'LOC'),
#  ('first', 'ORDINAL'),
#  ('two', 'CARDINAL'),
#  ('CME', 'ORG'),
#  ('third', 'ORDINAL'),
#  ('Earth', 'LOC'),
#  ('Earth', 'LOC'),
#  ('Earth', 'LOC'),
#  ('between 50 and 600 miles', 'CARDINAL'),
#  ('Earth', 'LOC'),
#  ('Three', 'CARDINAL'),
#  ('Pacific', 'LOC'),
#  ('Indian', 'NORP'),
#  ('R3', 'PRODUCT'),
#  ('1', 'CARDINAL'),
#  ('5', 'CARDINAL'),
#  ('the National Oceanic and Atmospheric Administration’s', 'ORG'),
#  ('about an hour', 'TIME'),
#  ('Earth', 'LOC'),
#  ('Thursday', 'DATE'),
#  ('morning', 'TIME'),
#  ('AT&T', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('The Space Weather Prediction Center', 'ORG'),
#  ('Kunches', 'PERSON'),
#  ('The Washington Post', 'ORG'),
#  ('the night hours', 'TIME'),
#  ('North America', 'LOC'),
#  ('Kunches', 'PERSON'),
#  ('daylight hours', 'TIME'),
#  ('3', 'CARDINAL'),
#  ('30', 'CARDINAL'),
#  ('megahertz', 'ORG'),
#  ('698', 'CARDINAL'),
#  ('806', 'CARDINAL'),
#  ('Wednesday', 'DATE'),
#  ('February of 2022', 'DATE'),
#  ('40', 'CARDINAL'),
#  ('CME', 'ORG'),
#  ('CME', 'ORG'),
#  ('more than a day', 'DATE'),
#  ('Earth', 'LOC'),
#  ('first', 'ORDINAL'),
#  ('two', 'CARDINAL'),
#  ('Wednesday', 'DATE'),
#  ('Earth', 'LOC'),
#  ('third', 'ORDINAL'),
#  ('Thursday', 'DATE'),
#  ('evening', 'TIME'),
#  ('Eastern', 'ORG'),
#  ('several hours', 'TIME'),
#  ('Sunday night', 'TIME'),
#  ('CME', 'ORG'),
#  ('Earth', 'LOC'),
#  ('the days ahead', 'DATE'),
#  ('three', 'CARDINAL'),
#  ('Active Region 3590', 'WORK_OF_ART')]

# %%
# Count every named entity
labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'CARDINAL': 16,
#          'DATE': 13,
#          'ORDINAL': 6,
#          'TIME': 8,
#          'ORG': 11,
#          'LOC': 13,
#          'NORP': 1,
#          'PRODUCT': 1,
#          'PERSON': 2,
#          'WORK_OF_ART': 1})

# %%
# 1.2.2 Get most frequent tokens
items = [x.text for x in doc.ents]
Counter(items).most_common(5)
# Out:
# [('Earth', 11), ('CME', 4), ('first', 3), ('two', 3), ('third', 3)]

# %%
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %%
#1.2.3 Pick a random integer K using Python random module, then pick 
#three consecutive sentences starting with Kth, and print these sentences. Note 
#that you must make sure all picked sentences are in the document.  

# Extract individual sentences
sentences = list(doc.sents)

# Pick a random integer K
K = random.randint(0, len(sentences)-3)

# Print the three consecutive sentences starting with the Kth sentence
for i in range(K, K+3):
    print(sentences[i].text.strip())
    
#Extract part-of-speech and lemmatize these consecutive sentences    
    sentence = sentences[i]
    lemmatized_tokens = [token.lemma_ for token in sentence]
    pos_tags= [token.pos_ for token in sentence]
    print("Lemmatized sentence:", ' '.join(lemmatized_tokens))
    print("POS tags:", pos_tags)
    print()
    
## In here the output is given for each kth sentence. that is starting with Sentence K and its corresponding Lemmatized sentences, its part of speech.
# Out:
# Flares and their associated radio bursts only impact dayside systems if at all,” Kunches said in an email.
# Lemmatized sentence: flare and their associated radio burst only impact dayside system if at all , " kunche say in an email .
# POS tags: ['NOUN', 'CCONJ', 'PRON', 'ADJ', 'NOUN', 'NOUN', 'ADV', 'VERB', 'VERB', 'NOUN', 'SCONJ', 'ADV', 'ADV', 'PUNCT', 'PUNCT', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'PUNCT']
#
# “And, even if this was to occur during your daylight hours, chances are near nil that cell service would be affected.
# Lemmatized sentence: " and , even if this be to occur during your daylight hour , chance be near nil that cell service would be affect .
# POS tags: ['PUNCT', 'CCONJ', 'PUNCT', 'ADV', 'SCONJ', 'PRON', 'AUX', 'PART', 'VERB', 'ADP', 'PRON', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'AUX', 'ADP', 'NOUN', 'SCONJ', 'NOUN', 'NOUN', 'AUX', 'AUX', 'VERB', 'PUNCT']
#
# ”Solar
# Lemmatized sentence: ”Solar
# POS tags: ['PUNCT']

# %%
# Get and print the entity annotation for each token of the Kth sentence  
kth_sentence = sentences[K]
for token in kth_sentence:
    print(token.text, token.ent_type_)
# Out:
# Flares
# and
# their
# associated
# radio
# bursts
# only
# impact
# dayside
# systems
# if
# at
# all
# ,
# ”
# Kunches PERSON
# said
# in
# an
# email
# .

# %%
displacy.render(kth_sentence, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Flares and their associated radio bursts only impact dayside systems if at all,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kunches
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said in an email. </div></span>

# %%
#options = {"compact": True, "bg": "#09a3d5",
#          "color": "white", "font": "Source Sans Pro"}
displacy.render(kth_sentence, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6e4dfeb3bac648bb8ba865aaa5d629d2-0" class="displacy" width="3200" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Flares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">associated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">radio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">bursts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">impact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">dayside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">all,”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Kunches</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">email.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-0" stroke-width="2px" d="M70,439.5 C70,2.0 1275.0,2.0 1275.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-1" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M205.0,441.5 L213.0,429.5 197.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-2" stroke-width="2px" d="M420,439.5 C420,177.0 915.0,177.0 915.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-3" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-4" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6e4dfeb3bac648bb8ba865aaa5d629d2-0-5" stroke-width="2px" d="M70,439.5 C70,89.5 920.0,89.5 920.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href=

# %%
# Visualize all the entities in the document
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  top-tier X-class solar flares launched off the sun between
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday and Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  occurred
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  apart, coming in at X1.9 and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     X1.6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  magnitude respectively. The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , the most powerful of the current
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  “solar cycle,” ranked an impressive X6.3.Solar flares, or bursts of radiation, are ranked on a scale that goes from A, B and C to M and X, in increasing order of intensity. They usually originate from sunspots, or bruiselike discolorations on the surface of the sun.Sunspots are most common near the height of the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  solar cycle. The current cycle, number
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , is expected to reach its peak
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The more sunspots, the more opportunities for solar flares.Solar flares and accompanying coronal mass ejections, or CMEs, can influence “space weather” across the solar system, and even here on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . CMEs are slower shock waves of magnetic energy from the sun. Flares can reach
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  in minutes, but CMEs usually take
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least a day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .All
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the X-class solar flares disrupted shortwave radio communications on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . But the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  flares did not release a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . And, after careful review, scientists confirmed that the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  also did not produce one. Therefore, no additional impact on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  is expected.High-frequency radio waves propagate by bouncing off electrons in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ’s ionosphere. That’s a layer of
# <mark class="entity" style="backgro

# %% [markdown]
# ### Task-2 De-Identification

# %%
#De-identify all person names (PERSON) in the webpage document with [REDACTED] and visualize them. 

filtered_document = " "
for token in doc:
    if token.ent_type_ == "PERSON":
        filtered_document += "[REDACTED] "
    else:
        filtered_document += token.text_with_ws

# %%
displacy.render(nlp(filtered_document), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  top-tier X-class solar flares launched off the sun between
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday and Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  occurred
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  apart, coming in at X1.9 and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     X1.6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  magnitude respectively. The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , the most powerful of the current
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  “solar cycle,” ranked an impressive X6.3.Solar flares, or bursts of radiation, are ranked on a scale that goes from A, B and C to M and X, in increasing order of intensity. They usually originate from sunspots, or bruiselike discolorations on the surface of the sun.Sunspots are most common near the height of the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  solar cycle. The current cycle, number
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , is expected to reach its peak
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The more sunspots, the more opportunities for solar flares.Solar flares and accompanying coronal mass ejections, or CMEs, can influence “space weather” across the solar system, and even here on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . CMEs are slower shock waves of magnetic energy from the sun. Flares can reach
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  in minutes, but CMEs usually take
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least a day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .All
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the X-class solar flares disrupted shortwave radio communications on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . But the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  flares did not release a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . And, after careful review, scientists confirmed that the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  also did not produce one. Therefore, no additional impact on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  is expected.High-frequency radio waves propagate by bouncing off electrons in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ’s ionosphere. That’s a layer of
# <mark class="entity" style="backgr

# %% [markdown]
# ### References
#
# [1]Dr.Liao's Code Example and tutorials :https://mymasonportal.gmu.edu/ultra/courses/_510861_1/cl/outline
# [2]Removing Personal information from Text: https://towardsdatascience.com/remove-personal-information-from-a-text-with-python-part-ii-ner-2e6529d409a6 posted on TowardsDataScience by Leo Van der Meulen on August 12, 2021
